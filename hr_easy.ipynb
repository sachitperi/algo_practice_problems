# %% [markdown]
# An array is a type of data structure that stores elements of the same type in a contiguous block of memory. In an array, , of size , each memory location has some unique index,  (where ), that can be referenced as  (you may also see it written as ).
#
# Given an array, , of  integers, print each element in reverse order as a single line of space-separated integers.
#
# Note: If you've already solved our C++ domain's Arrays Introduction challenge, you may want to skip this.
#
# Input Format
#
# The first line contains an integer,  (the number of integers in ).
# The second line contains  space-separated integers describing .
#
# Constraints
#
# Output Format
#
# Print all  integers in  in reverse order as a single line of space-separated integers.
#
# Sample Input 1
#
# CopyDownload
# Array: arr
# 1
# 4
# 3
# 2
#
#
# 4
# 1 4 3 2
# Sample Output 1
#
# 2 3 4 1
#
# ![problem_image](./images/Arrays-DS.png)

# %%
#!/bin/python3

import math
import os
import random
import re
import sys

# Complete the reverseArray function below.
def reverseArray(a):
    len_a = len(a)
    reverse_array = []
    for num in range(1, len_a+1):
        reverse_array.append(a[-num])
    return reverse_array
if __name__ == '__main__':
    fptr = open(os.environ['OUTPUT_PATH'], 'w')

    arr_count = int(input())

    arr = list(map(int, input().rstrip().split()))

    res = reverseArray(arr)

    fptr.write(' '.join(map(str, res)))
    fptr.write('\n')

    fptr.close()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-28-b77e592c7464> in <module>
#      15
#      16 if __name__ == '__main__':
# ---> 17     fptr = open(os.environ['OUTPUT_PATH'], 'w')
#      18
#      19     arr_count = int(input())
#
# ~/opt/anaconda3/lib/python3.7/os.py in __getitem__(self, key)
#     676         except KeyError:
#     677             # raise KeyError with the original key value
# --> 678             raise KeyError(key) from None
#     679         return self.decodevalue(value)
#     680
#
# KeyError: 'OUTPUT_PATH'

# %%
def reverseArray(a):
    num=0
    while num <= len(a)/2:
        inti = a[num] # a[0], a[1]
        final = a[-()] # a[-1], a[-2]
        a[num] = final # a[0] = a[0]
        a[-(num+1)] = inti
        num = num+1
    return a

def reverseArray(a):
    num=0
    size = len(a)
    while num++ <= len(a)//2:
        temp = a[num]
        a[num] = a[size - num - 1] # a[0] = a[4]
        a[size-num - 1] = temp
    return a

# %% [markdown]
# ![problem_image](./images/2d-array-ds-1.png)
#
# ![problem_image](./images/2d-array-ds-2.png)
#
# ![problem_image](./images/2d-array-ds-3.png)
#
# ![problem_image](./images/2d-array-ds-4.png)

# %%
#!/bin/python3

import math
import os
import random
import re
import sys

# Complete the hourglassSum function below.
def hourglassSum(a):
    array_sum = -9*8
    for i in range(len(a)-2):
        for j in range(len(a[i])-2):
            required_array_sum = sum(a[i][j:j+3]) + sum(a[i+1][j+1:j+2]) + sum(a[i+2][j:j+3])
            array_sum = array_sum if required_array_sum < array_sum else required_array_sum
    return array_sum

if __name__ == '__main__':
    fptr = open(os.environ['OUTPUT_PATH'], 'w')

    arr = []

    for _ in range(6):
        arr.append(list(map(int, input().rstrip().split()))) 

    result = hourglassSum(arr)

    fptr.write(str(result) + '\n')

    fptr.close()

# %%
# Complete the hourglassSum function below.
def hourglassSum(a):
    max_array_sum = -9*8
    for i in range(len(a)-2):
        for j in range(len(a[i])-2):
            cur_array_sum = sum(a[i][j:j+3]) + sum(a[i+1][j+1:j+2]) + sum(a[i+2][j:j+3])
            max_array_sum = max(max_array_sum, cur_array_sum)
    return max_array_sum

# %% [markdown]
# ![problem_image](./images/left-rotation-1.png)
#
# ![problem_image](./images/left-rotation-2.png)

# %%
#!/bin/python3

import math
import os
import random
import re
import sys



if __name__ == '__main__':
    nd = input().split()

    n = int(nd[0])

    d = int(nd[1])

    a = list(map(int, input().rstrip().split()))

    left_array = a[d:]
    right_array = a[:d]
    a = ' '.join(map(str, left_array + right_array))
    print(a)

# %% [markdown]
# ![problem_image](./images/print-elements-of-linked-list-1.png)
#
# ![problem_image](./images/print-elements-of-linked-list-2.png)

# %%
#!/bin/python3

import math
import os
import random
import re
import sys

class SinglyLinkedListNode:
    def __init__(self, node_data):
        self.data = node_data
        self.next = None

class SinglyLinkedList:
    def __init__(self):
        self.head = None
        self.tail = None

    def insert_node(self, node_data):
        node = SinglyLinkedListNode(node_data)

        if not self.head:
            self.head = node
        else:
            self.tail.next = node


        self.tail = node

# Complete the printLinkedList function below.

#
# For your reference:
#
# SinglyLinkedListNode:
#     int data
#     SinglyLinkedListNode next
#
#
def printLinkedList(head):
    print(head.data)
    if head.next != None:
        head = head.next
        printLinkedList(head)

if __name__ == '__main__':
    llist_count = int(input())

    llist = SinglyLinkedList()

    for _ in range(llist_count):
        llist_item = int(input())
        llist.insert_node(llist_item)

    printLinkedList(llist.head)

# %% [markdown]
# ![problem_image](./images/insert-a-node-at-head-of-linkedlist-1.png)
#
# ![problem_image](./images/insert-a-node-at-head-of-linkedlist-2.png)

# %%
#!/bin/python3

import math
import os
import random
import re
import sys

class SinglyLinkedListNode:
    def __init__(self, node_data):
        self.data = node_data
        self.next = None

class SinglyLinkedList:
    def __init__(self):
        self.head = None
        self.tail = None

def print_singly_linked_list(node, sep, fptr):
    while node:
        fptr.write(str(node.data))

        node = node.next

        if node:
            fptr.write(sep)

# Complete the insertNodeAtHead function below.

#
# For your reference:
#
# SinglyLinkedListNode:
#     int data
#     SinglyLinkedListNode next
#
#
def insertNodeAtHead(llist, data):
    # Write your code here
    node = SinglyLinkedListNode(data)
    node.next = llist
    return node

if __name__ == '__main__':

# %% [markdown]
# ![problem_image](./images/insert-a-node-at-tail-of-linkedlist-1.png)
#
# ![problem_image](./images/insert-a-node-at-tail-of-linkedlist-2.png)

# %%
#!/bin/python3

import math
import os
import random
import re
import sys

class SinglyLinkedListNode:
    def __init__(self, node_data):
        self.data = node_data
        self.next = None

class SinglyLinkedList:
    def __init__(self):
        self.head = None

def print_singly_linked_list(node, sep, fptr):
    while node:
        fptr.write(str(node.data))

        node = node.next

        if node:
            fptr.write(sep)

# Complete the insertNodeAtTail function below.

#
# For your reference:
#
# SinglyLinkedListNode:
#     int data
#     SinglyLinkedListNode next
#
#
def insertNodeAtTail(head, data):
    node = SinglyLinkedListNode(data)
    if head:
        current = head
        while current.next:
            current = current.next
        current.next = node
    else:
        head = node
    return head


if __name__ == '__main__':
    fptr = open(os.environ['OUTPUT_PATH'], 'w')

    llist_count = int(input())

    llist = SinglyLinkedList()

    for i in range(llist_count):
        llist_item = int(input())
        llist_head = insertNodeAtTail(llist.head, llist_item)
        llist.head = llist_head

    print_singly_linked_list(llist.head, '\n', fptr)
    fptr.write('\n')

    fptr.close()

# %% [markdown]
# How is above code different from the below code
#
# def insertNodeAtTail(head, data):
#     new_node = SinglyLinkedListNode(data)
#     if head:
#         while head.next != None:
#             head = head.next
#         head.next = new_node
#     else:
#         head = new_node
#     return head

# %% [markdown]
# ![problem_image](./images/Insert-a-node-at-a-specific-position-in-a-linked-list-1.png)
#
# ![problem_image](./images/Insert-a-node-at-a-specific-position-in-a-linked-list-2.png)

# %%
#!/bin/python3

import math
import os
import random
import re
import sys

class SinglyLinkedListNode:
    def __init__(self, node_data):
        self.data = node_data
        self.next = None

class SinglyLinkedList:
    def __init__(self):
        self.head = None
        self.tail = None

    def insert_node(self, node_data):
        node = SinglyLinkedListNode(node_data)

        if not self.head:
            self.head = node
        else:
            self.tail.next = node


        self.tail = node

def print_singly_linked_list(node, sep, fptr):
    while node:
        fptr.write(str(node.data))

        node = node.next

        if node:
            fptr.write(sep)

# Complete the insertNodeAtPosition function below.

#
# For your reference:
#
# SinglyLinkedListNode:
#     int data
#     SinglyLinkedListNode next
#
#
def insertNodeAtPosition(head, data, position):
    node = SinglyLinkedListNode(data)
    pos = 0
    current = head
    while pos != position-1:
        current = current.next
        pos+=1
    node.next = current.next
    current.next = node
    return head

if __name__ == '__main__':
    fptr = open(os.environ['OUTPUT_PATH'], 'w')

    llist_count = int(input())

    llist = SinglyLinkedList()

    for _ in range(llist_count):
        llist_item = int(input())
        llist.insert_node(llist_item)

    data = int(input())

    position = int(input())

    llist_head = insertNodeAtPosition(llist.head, data, position)

    print_singly_linked_list(llist_head, ' ', fptr)
    fptr.write('\n')

    fptr.close()

# %% [markdown]
# https://www.hackerrank.com/challenges/delete-a-node-from-a-linked-list/problem
#
# ![problem_image](./images/delete-node-1.png)
#
# ![problem_image](./images/delete-node-2.png)

# %%
#!/bin/python3

import math
import os
import random
import re
import sys

class SinglyLinkedListNode:
    def __init__(self, node_data):
        self.data = node_data
        self.next = None

class SinglyLinkedList:
    def __init__(self):
        self.head = None
        self.tail = None

    def insert_node(self, node_data):
        node = SinglyLinkedListNode(node_data)

        if not self.head:
            self.head = node
        else:
            self.tail.next = node


        self.tail = node

def print_singly_linked_list(node, sep, fptr):
    while node:
        fptr.write(str(node.data))

        node = node.next

        if node:
            fptr.write(sep)

# Complete the deleteNode function below.

#
# For your reference:
#
# SinglyLinkedListNode:
#     int data
#     SinglyLinkedListNode next
#
#
def deleteNode(head, position):
    pos = 0
    current = head
    next_p = current.next
    while pos != position-1:
        current = current.next
        next_p = next_p.next
        pos+=1
    if next_p.next == None:
        current.next = None
    else:
        current.next = next_p.next
    return head

if __name__ == '__main__':
    fptr = open(os.environ['OUTPUT_PATH'], 'w')

    llist_count = int(input())

    llist = SinglyLinkedList()

    for _ in range(llist_count):
        llist_item = int(input())
        llist.insert_node(llist_item)

    position = int(input())

    llist1 = deleteNode(llist.head, position)

    print_singly_linked_list(llist1, ' ', fptr)
    fptr.write('\n')

    fptr.close()

# %% [markdown]
# Got hidden testcase 2 wrong
# input : 7
# 11
# 12
# 8
# 18
# 16
# 5
# 18
# 0
#
# expected_outpuy: 12 8 18 16 5 18

# %%
# solution solving all test cases

def deleteNode(head, position):
    if head:
        if position == 0:
            head = head.next
        else:
            previous = None
            current = head
            current_position = 0
            while (current_position < position) and (current.next is not None):
                previous = current
                current = current.next
                current_position += 1
            previous.next = current.next
    return head

# %% [markdown]
# https://www.hackerrank.com/challenges/print-the-elements-of-a-linked-list-in-reverse/problem

# %%
#!/bin/python3

import math
import os
import random
import re
import sys

class SinglyLinkedListNode:
    def __init__(self, node_data):
        self.data = node_data
        self.next = None

class SinglyLinkedList:
    def __init__(self):
        self.head = None
        self.tail = None

    def insert_node(self, node_data):
        node = SinglyLinkedListNode(node_data)

        if not self.head:
            self.head = node
        else:
            self.tail.next = node


        self.tail = node

def print_singly_linked_list(node, sep):
    while node:
        print(node.data, end='')

        node = node.next

        if node:
            print(sep, end='')

# Complete the reversePrint function below.

#
# For your reference:
#
# SinglyLinkedListNode:
#     int data
#     SinglyLinkedListNode next
#
#

def reversePrint(head):
    if head:
        stack = [head]
        while stack[-1].next:
            node = stack[-1]
            stack.append(node.next)
        while stack:
            node = stack.pop()
            print(node.data)


def print_reverse_recursive(head):
    if head:
        print_reverse_iterative(head.next)
        print(head.data)

# class SinglyLinkedListInsertatStart:
#     def __init__(self):
#         self.head = None
#         self.tail = None

#     def insert_node(self, node_data):
#         node = SinglyLinkedListNode(node_data)

#         if not self.head:
#             self.head = node
#         else:
#             node.next = self.head
#             self.head = node

# def reversePrint(head):
#     if head:
#         reverse_list = SinglyLinkedListInsertatStart()
#         while head:
#             reverse_list.insert_node(head.data)
#             head = head.next
#     print(print_singly_linked_list(reverse_list.head, ' '))
#     return reverse_list.head


if __name__ == '__main__':
    tests = int(input())

    for tests_itr in range(tests):
        llist_count = int(input())

        llist = SinglyLinkedList()

        for _ in range(llist_count):
            llist_item = int(input())
            llist.insert_node(llist_item)

        reversePrint(llist.head)

# %% [markdown]
# ### Reverse a linked list
# https://www.hackerrank.com/challenges/reverse-a-linked-list/problem

# %%
#!/bin/python3

import math
import os
import random
import re
import sys

class SinglyLinkedListNode:
    def __init__(self, node_data):
        self.data = node_data
        self.next = None

class SinglyLinkedList:
    def __init__(self):
        self.head = None
        self.tail = None

    def insert_node(self, node_data):
        node = SinglyLinkedListNode(node_data)

        if not self.head:
            self.head = node
        else:
            self.tail.next = node


        self.tail = node

def print_singly_linked_list(node, sep, fptr):
    while node:
        fptr.write(str(node.data))

        node = node.next

        if node:
            fptr.write(sep)

# %%
arr1 = [1, 2, 3, 4, 5]

llist_count = len(arr1)

llist = SinglyLinkedList()

for i in range(llist_count):
    print(i, arr1[i])
    llist_item = int(arr1[i])
    llist.insert_node(llist_item)

# for tests_itr in range(tests):
#     llist_count = int(input())

#     llist = SinglyLinkedList()

#     for _ in range(llist_count):
#         llist_item = int(input())
#         llist.insert_node(llist_item)

#     llist1 = reverse(llist.head)

#     print_singly_linked_list(llist1, ' ', fptr)
#     fptr.write('\n')

# fptr.close()
# Out:
# 0 1
# 1 2
# 2 3
# 3 4
# 4 5

# %%
llist_count
# Out:
# 5

# %%
fptr = open(os.path.join(os.getcwd(), "output", "llist.txt"), 'w')
print_singly_linked_list(llist.head, ' ', fptr)
fptr.close()

# %%
# Complete the reverse function below.

#
# For your reference:
#
# SinglyLinkedListNode:
#     int data
#     SinglyLinkedListNode next
#
#
# [1>>2>>3>>4>>5]
# [1>> None, 2>>1, 3>>2, 4>>3, 5>>4]

def reverse(head):
    previous = None
    while head:
        current_node = head # [1], [2]
        next_node = head.next # [2], [3]
        head.next = previous # [1 >> None], [2>>1]
        previous = current_node # [setting previous to 1]
        if next_node==None:
            break
        else:
            head = next_node # [moved on to 2], [moved on to 3]
        print(current_node.data, next_node, head.data)
    return head

# def reverse(head):
#     rev_list = []
#     while head:
#         rev_list = [head.data] + rev_list
#         head = head.next
#     rev_llist = SinglyLinkedList()
#     for ele in rev_list:
#         rev_llist.insert_node(ele)      
#     return rev_llist.head

fptr = open(os.path.join(os.getcwd(), "output", "llist.txt"), 'w')
# rev_list, llist1 = reverse(llist.head)
# print(rev_list)
llist1 = reverse(llist.head)
print(llist1)
print_singly_linked_list(llist1, ' ', fptr)
fptr.close()
# Out:
# 1 <__main__.SinglyLinkedListNode object at 0x10add0610> 2
# 2 <__main__.SinglyLinkedListNode object at 0x10add0d10> 3
# 3 <__main__.SinglyLinkedListNode object at 0x109180090> 4
# 4 <__main__.SinglyLinkedListNode object at 0x10b1ec250> 5
# ...

# %% [markdown]
# ### Compare Linkedlist
#
# https://www.hackerrank.com/challenges/compare-two-linked-lists/problem

# %%
#!/bin/python3

import os
import sys

class SinglyLinkedListNode:
    def __init__(self, node_data):
        self.data = node_data
        self.next = None

class SinglyLinkedList:
    def __init__(self):
        self.head = None
        self.tail = None

    def insert_node(self, node_data):
        node = SinglyLinkedListNode(node_data)

        if not self.head:
            self.head = node
        else:
            self.tail.next = node


        self.tail = node

def print_singly_linked_list(node, sep, fptr):
    while node:
        fptr.write(str(node.data))

        node = node.next

        if node:
            fptr.write(sep)

# Complete the compare_lists function below.

#
# For your reference:
#
# SinglyLinkedListNode:
#     int data
#     SinglyLinkedListNode next
#
#

def compare_lists(llist1, llist2):
    compare = 1
    while llist1!= None and llist2 != None and compare:
        if llist2.data == llist1.data:
            if (llist1.next and llist2.next) or (llist1.next == llist2.next) :
                compare = 1
                llist1 = llist1.next
                llist2 = llist2.next
            else:
                compare = 0
        else:
            compare = 0

    return compare

# def compare_lists(llist1, llist2):
#     list1 = []
#     list2 = []
#     while llist1: 
#         list1.append(llist1.data)
#         llist1 = llist1.next
#     while llist2: 
#         list2.append(llist2.data)
#         llist2 = llist2.next

#     return list1 == list2


if __name__ == '__main__':
    fptr = open(os.environ['OUTPUT_PATH'], 'w')

    tests = int(input())

    for tests_itr in range(tests):
        llist1_count = int(input())

        llist1 = SinglyLinkedList()

        for _ in range(llist1_count):
            llist1_item = int(input())
            llist1.insert_node(llist1_item)
            
        llist2_count = int(input())

        llist2 = SinglyLinkedList()

        for _ in range(llist2_count):
            llist2_item = int(input())
            llist2.insert_node(llist2_item)

        result = compare_lists(llist1.head, llist2.head)

        fptr.write(str(int(result)) + '\n')

    fptr.close()

# %% [markdown]
# ### merge 2 linkedlist
#
# https://www.hackerrank.com/challenges/merge-two-sorted-linked-lists/problem

# %%
#!/bin/python3

import math
import os
import random
import re
import sys

class SinglyLinkedListNode:
    def __init__(self, node_data):
        self.data = node_data
        self.next = None

class SinglyLinkedList:
    def __init__(self):
        self.head = None
        self.tail = None

    def insert_node(self, node_data):
        node = SinglyLinkedListNode(node_data)

        if not self.head:
            self.head = node
        else:
            self.tail.next = node


        self.tail = node

def print_singly_linked_list(node, sep, fptr):
    while node:
        fptr.write(str(node.data))

        node = node.next

        if node:
            fptr.write(sep)

# Complete the getNode function below.

#
# For your reference:
#
# SinglyLinkedListNode:
#     int data
#     SinglyLinkedListNode next
#
#

# def getNode(head, positionFromTail):
#     arr = []
#     while head:
#         arr.append(head.data)
#         head = head.next
    
#     return arr[-positionFromTail-1]

def getNode(head, positionFromTail):
    no_of_pointors = 0
    pointer = 0
    current_node = head

    while current_node:
        no_of_pointors +=1
        current_node = current_node.next
    
    pointortoget = no_of_pointors - positionFromTail -1

    while pointer != pointortoget:
        pointer += 1
        head = head.next

    return head.data


if __name__ == '__main__':
    fptr = open(os.environ['OUTPUT_PATH'], 'w')

    tests = int(input())

    for tests_itr in range(tests):
        llist_count = int(input())

        llist = SinglyLinkedList()

        for _ in range(llist_count):
            llist_item = int(input())
            llist.insert_node(llist_item)

        position = int(input())

        result = getNode(llist.head, position)

        fptr.write(str(result) + '\n')

    fptr.close()

# %% [markdown]
# ### delet duplicate nodes from a sorted linkedlist
#
# https://www.hackerrank.com/challenges/delete-duplicate-value-nodes-from-a-sorted-linked-list/problem

# %%
#!/bin/python3

import math
import os
import random
import re
import sys

class SinglyLinkedListNode:
    def __init__(self, node_data):
        self.data = node_data
        self.next = None

class SinglyLinkedList:
    def __init__(self):
        self.head = None
        self.tail = None

    def insert_node(self, node_data):
        node = SinglyLinkedListNode(node_data)

        if not self.head:
            self.head = node
        else:
            self.tail.next = node


        self.tail = node

def print_singly_linked_list(node, sep, fptr):
    while node:
        fptr.write(str(node.data))

        node = node.next

        if node:
            fptr.write(sep)

# Complete the removeDuplicates function below.

#
# For your reference:
#
# SinglyLinkedListNode:
#     int data
#     SinglyLinkedListNode next
#
#
# def removeDuplicates(head):
#     arr = []
#     while head:
#         arr.append(head.data)
#         head = head.next

#     arr = list(set(arr))
#     llist = SinglyLinkedList()
#     for ele in arr:
#         llist.insert_node(ele)
    
#     return llist.head

# def removeDuplicates(head):
#     arr = []
#     while head:
#         if head.data not in arr:
#             arr.append(head.data)
#         head = head.next

#     llist = SinglyLinkedList()
#     for ele in arr:
#         llist.insert_node(ele)
    
#     return llist.head

def removeDuplicates(head):
    arr = []
    previous = None
    current_node = head
    while current_node:
        next_node = current_node.next
        if current_node.data not in arr:
            arr.append(current_node.data)
            previous = current_node
            current_node = next_node 
        else:
            previous.next = next_node
            current_node = next_node
    
    return head



if __name__ == '__main__':
    fptr = open(os.environ['OUTPUT_PATH'], 'w')

    t = int(input())

    for t_itr in range(t):
        llist_count = int(input())

        llist = SinglyLinkedList()

        for _ in range(llist_count):
            llist_item = int(input())
            llist.insert_node(llist_item)

        llist1 = removeDuplicates(llist.head)

        print_singly_linked_list(llist1, ' ', fptr)
        fptr.write('\n')

    fptr.close()

# %% [markdown]
# ### Find Merge Point of Two Lists
#
# https://www.hackerrank.com/challenges/find-the-merge-point-of-two-joined-linked-lists/problem

# %%
#!/bin/python3

import math
import os
import random
import re
import sys

class SinglyLinkedListNode:
    def __init__(self, node_data):
        self.data = node_data
        self.next = None

class SinglyLinkedList:
    def __init__(self):
        self.head = None
        self.tail = None

    def insert_node(self, node_data):
        node = SinglyLinkedListNode(node_data)

        if not self.head:
            self.head = node
        else:
            self.tail.next = node


        self.tail = node

def print_singly_linked_list(node, sep, fptr):
    while node:
        fptr.write(str(node.data))

        node = node.next

        if node:
            fptr.write(sep)

# Complete the findMergeNode function below.

#
# For your reference:
#
# SinglyLinkedListNode:
#     int data
#     SinglyLinkedListNode next
#
#
def findMergeNode(head1, head2):
    arr1 = []
    arr2 = []
    while head1:
        arr1.append(head1.data)
        head1 = head1.next

    while head2:
        arr2.append(head2.data)
        head2 = head2.next

    arr1_len = len(arr1)
    arr2_len = len(arr2)
    i = 1
    while i < (min(arr1_len, arr2_len)):
        if arr1[-i] != arr2[-i]:
            break
        i+=1

    return arr1[-i+1]



if __name__ == '__main__':
    fptr = open(os.environ['OUTPUT_PATH'], 'w')

    tests = int(input())

    for tests_itr in range(tests):
        index = int(input())

        llist1_count = int(input())

        llist1 = SinglyLinkedList()

        for _ in range(llist1_count):
            llist1_item = int(input())
            llist1.insert_node(llist1_item)
            
        llist2_count = int(input())

        llist2 = SinglyLinkedList()

        for _ in range(llist2_count):
            llist2_item = int(input())
            llist2.insert_node(llist2_item)
            
        ptr1 = llist1.head;
        ptr2 = llist2.head;

        for i in range(llist1_count):
            if i < index:
                ptr1 = ptr1.next
                
        for i in range(llist2_count):
            if i != llist2_count-1:
                ptr2 = ptr2.next

        ptr2.next = ptr1

        result = findMergeNode(llist1.head, llist2.head)

        fptr.write(str(result) + '\n')

    fptr.close()
